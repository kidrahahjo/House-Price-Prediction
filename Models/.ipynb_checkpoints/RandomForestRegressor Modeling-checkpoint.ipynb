# %%
import pandas as pd
import pandasql as pdsql
import seaborn as sns
import signac
import random_forest

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_log_error

sns.set_theme(style="whitegrid")

# %%
project = signac.get_project('dataset_per_rsquared')

# %%
project
# Out:
# Project.get_project('/home/kidrahahjo/Machine-Learning/House Price Regression')

# %%
for job in project:
    if job.sp.get('10%') is not None:
        req_job = job
        break

# %%
req_job
# Out:
# Job(project=Project.get_project('/home/kidrahahjo/Machine-Learning/House Price Regression'), statepoint={'10%': ['OverallQual', 'GrLivArea', 'GarageCars', 'ExterQual', 'GarageArea', 'TotalBsmtSF', 'BsmtQual', '1stFlrSF', 'KitchenQual', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'GarageFinish', 'YearRemodAdd', 'GarageYrBlt', 'MasVnrArea', 'Fireplaces', 'HeatingQC', 'BsmtFinSF1', 'Foundation', 'GarageType', 'LotFrontage', 'WoodDeckSF', '2ndFlrSF', 'SalePrice'], 'val_mean_squared_log_error': 0.0204, 'submit_mean_squared_log_error': 0.14981})

# %%
features =req_job.sp.get('10%')
features
# Out:
# ['OverallQual',
#  'GrLivArea',
#  'GarageCars',
#  'ExterQual',
#  'GarageArea',
#  'TotalBsmtSF',
#  'BsmtQual',
#  '1stFlrSF',
#  'KitchenQual',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'GarageFinish',
#  'YearRemodAdd',
#  'GarageYrBlt',
#  'MasVnrArea',
#  'Fireplaces',
#  'HeatingQC',
#  'BsmtFinSF1',
#  'Foundation',
#  'GarageType',
#  'LotFrontage',
#  'WoodDeckSF',
#  '2ndFlrSF',
#  'SalePrice']

# %%
dataset_train = pd.read_csv("../10rsq_final_data.csv")
dataset_test = pd.read_csv("../Data/test.csv")[['Id'] + features[:-1]]

# %%
categorical_cols = []
for column in features[:-1]:
    if str(dataset_train[column].dtype) == 'object':
        categorical_cols.append(column)
        dataset_test[column] = dataset_test[column].fillna('None')
        dataset_train[column] = dataset_train[column].fillna('None')
        labelencoder = LabelEncoder()
        dataset_test[column] = pd.Series(labelencoder.fit_transform(dataset_test[column]))
        dataset_train[column] = pd.Series(labelencoder.fit_transform(dataset_train[column]))

non_cat_cols = list(set(features).difference(set(categorical_cols)))

# %%
dataset_test = dataset_test.fillna(-1)
dataset_train = dataset_train.fillna(-1)

# %%
X = dataset_train[features[:-1]]
y = dataset_train['SalePrice']
test_X = dataset_test[features[:-1]]
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=0.2)

# %%
X.head()

# %%
y.head()

# %%
dataset_test.head()

# %%
regr = RandomForestRegressor()
regr.fit(train_X, train_y)
val_r2_score = regr.score(val_X, val_y)
val_pred = regr.predict(val_X)
val_msle_score = mean_squared_log_error(val_y, val_pred)

# %%
val_r2_score

# %%
val_msle_score

# %%
final_predict = regr.predict(test_X)

# %%
final_predict = pd.DataFrame({'Id': list(dataset_test['Id']), 'SalePrice': final_predict, })
final_predict

# %%
final_predict.to_csv('10r2sample_rfr.csv', index=False)

# %%
req_job.sp['val_mean_squared_log_error'] = 0.0204
req_job.sp['submit_mean_squared_log_error'] = 0.14981

# %%
train_X
# Out:
#       OverallQual  GrLivArea  GarageCars  ExterQual  GarageArea  TotalBsmtSF  \
# 1223            5       2136           2          3         528         2136
# 758             7       1501           2          3         440          744
# 90              4       1040           2          3         420            0
# 815             7       1661           2          3         598         1649
# 448             6       1376           1          3         198          780
# ...           ...        ...         ...        ...         ...          ...
# 1287            5       1582           2          3         390         1624
# 1171            6       1261           2          3         433         1261
# 613             5       1120           0          3           0         1120
# 710             3        729           0          2           0          270
# 1251            7       1405           2          2         478         1405
#
#       BsmtQual  1stFlrSF  KitchenQual  FullBath  ...  GarageYrBlt  MasVnrArea  \
# 1223         4      2136            3         2  ...       1951.0        44.0
# 758          2       757            3         2  ...       1999.0       360.0
# 90           3      1040            3         1  ...       1950.0         0.0
# 815          2      1661            2         2  ...       1998.0       442.0
# 448          4       780            3         2  ...       1937.0         0.0
# ...        ...       ...          ...       ...  ...          ...         ...
# 1287         4      1582            3         2  ...       1964.0       621.0
# 1171         4      1261            3         1  ...       1958.0         0.0
# 613          2      1120            3         1  ...         -1.0         0.0
# 710          4       729            3         1  ...         -1.0         0.0
# 1251         2      1405            2         2  ...       2003.0       163.0
#
#       Fireplaces  HeatingQC  BsmtFinSF1  Foundation  GarageType  LotFrontage  \
# 1223           0          4         756           1           5         89.0
# 758            0          2         549           2           5         24.0
# 90             0          4           0           3           5         60.0
# 815            0          0           0           2           1         48.0
# 448            1          4           0           0           5         50.0
# ...          ...        ...         ...         ...         ...          ...
# 1287           0          1         812           1           1         -1.0
# 1171           1          0         662           1           1         76.0
# 613            0          0         206           2           6         70.0
# 710            0          2           0           1           6         56.0
# 1251           1          0           0           2           1         -1.0
#
#       WoodDeckSF  2ndFlrSF
# 1223           0         0
# 758            0       744
# 90             0         0
# 815            0         0
# 448            0       596
# ...          ...       ...
# 1287         168         0
# 1171           0         0
# 613            0         0
# 710            0         0
# 1251         148         0
#
# [1168 rows x 24 columns]
