# %%
import pandas as pd
import pandasql as pdsql
import seaborn as sns
import signac
import scipy 
import clean_data
import numpy as np

from matplotlib import pyplot as plt
from matplotlib.pyplot import show
from sklearn.preprocessing import LabelEncoder

sns.set_theme(style="whitegrid")

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Dataset

# %%
dataset = pd.read_csv("/home/kidrahahjo/Machine-Learning/House Price Regression/Raw Data/train.csv")

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Project
# Initialize project for storing hyper parameters

# %%
project = signac.get_project('project-hyper-params')

# %% [markdown]
# ## Null value cleaning
# Remove columns where null values are greater that 70%

# %%
null_cleaned_data = clean_data.remove_null(dataset, 70)
# Out:
# The features for which null values were greater than 70% are Alley, PoolQC, Fence, MiscFeature

# %%
null_cleaned_data
# Out:
#       HalfBath  3SsnPorch GarageFinish  LotArea  TotalBsmtSF  MSSubClass  \
# 0            1          0          RFn     8450          856          60
# 1            0          0          RFn     9600         1262          20
# 2            1          0          RFn    11250          920          60
# 3            0          0          Unf     9550          756          70
# 4            1          0          RFn    14260         1145          60
# ...        ...        ...          ...      ...          ...         ...
# 1455         1          0          RFn     7917          953          60
# 1456         0          0          Unf    13175         1542          20
# 1457         0          0          RFn     9042         1152          70
# 1458         0          0          Unf     9717         1078          20
# 1459         1          0          Fin     9937         1256          20
#
#      FireplaceQu KitchenQual Exterior1st  YearBuilt  ... ExterCond  FullBath  \
# ...

# %% [markdown]
# ## R-squared cleaning
# We will first analyse how much each column explains the variance in `SalePrice` and then reject variables according to a specific minimum value

# %%
rsquared_dataset = clean_data.analyse_rsquared(dataset)
rsquared_dataset.head()
# Out:
#          label  variance_explained
# 0    SalePrice          100.000000
# 1  OverallQual           62.565189
# 2    GrLivArea           50.214865
# 3   GarageCars           41.012394
# 4    ExterQual           40.562084

# %%
def show_values_on_bars(graph, total):
    "Show actual values on plot"
    for p in ax.patches:
        height = p.get_height()
        graph.text(p.get_x() + p.get_width() / 2.,
                height + 3,
                '{:1.2f}'.format((height / 1.23) / total),
                ha="center")
    show()
    
_, ax = plt.subplots(figsize=(100, 16))
total = len(rsquared_dataset['label'])
graph = sns.barplot(x='label', y='variance_explained', data=rsquared_dataset, ax=ax)
show_values_on_bars(graph, total)

# %% [markdown]
# ### Select minimum variance as 10 %

# %%
selected_data = clean_data.store_selected_rsquared_limit(null_cleaned_data, rsquared_dataset, 10, "10rsq_final_data")
selected_data.head()
# Out:
#    SalePrice  OverallQual  GrLivArea  GarageCars ExterQual  GarageArea  \
# 0     208500            7       1710           2        Gd         548
# 1     181500            6       1262           2        TA         460
# 2     223500            7       1786           2        Gd         608
# 3     140000            7       1717           3        TA         642
# 4     250000            8       2198           3        Gd         836
#
#    TotalBsmtSF  1stFlrSF BsmtQual KitchenQual  ...  GarageYrBlt  Fireplaces  \
# 0          856       856       Gd          Gd  ...       2003.0           0
# 1         1262      1262       Gd          TA  ...       1976.0           1
# 2          920       920       Gd          Gd  ...       2001.0           1
# 3          756       961       TA          Gd  ...       1998.0           1
# 4         1145      1145       Gd          Gd  ...       2000.0           1
#
#    GarageFinish  GarageType  HeatingQC  BsmtFinSF1  Foundation LotFrontage  \
# ...

# %% [markdown]
# #### Store to project

# %%
features = list(selected_data.columns)
project.open_job({'10%': features, 'No of features': len(features)}).init()
# Out:
# Job(project=Project.get_project('/home/kidrahahjo/Machine-Learning/House Price Regression'), statepoint={'10%': ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'ExterQual', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'BsmtQual', 'KitchenQual', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'GarageYrBlt', 'Fireplaces', 'GarageFinish', 'GarageType', 'HeatingQC', 'BsmtFinSF1', 'Foundation', 'LotFrontage', 'WoodDeckSF', '2ndFlrSF'], 'No of features': 25})

# %% [markdown]
# ### Select minimum variance as 5 %

# %%
selected_data = clean_data.store_selected_rsquared_limit(null_cleaned_data, rsquared_dataset, 5, "5rsq_final_data")
selected_data.head()
# Out:
#    SalePrice  OverallQual  GrLivArea  GarageCars ExterQual  GarageArea  \
# 0     208500            7       1710           2        Gd         548
# 1     181500            6       1262           2        TA         460
# 2     223500            7       1786           2        Gd         608
# 3     140000            7       1717           3        TA         642
# 4     250000            8       2198           3        Gd         836
#
#    TotalBsmtSF  1stFlrSF BsmtQual KitchenQual  ...  OpenPorchSF  HalfBath  \
# 0          856       856       Gd          Gd  ...           61         1
# 1         1262      1262       Gd          TA  ...            0         0
# 2          920       920       Gd          Gd  ...           42         1
# 3          756       961       TA          Gd  ...           35         0
# 4         1145      1145       Gd          Gd  ...           84         1
#
#    BsmtExposure  LotArea  LotShape  CentralAir  GarageCond Electrical  \
# ...

# %% [markdown]
# #### Store to project

# %%
features = list(selected_data.columns)
project.open_job({'5%': features, 'No of features': len(features)}).init()
# Out:
# Job(project=Project.get_project('/home/kidrahahjo/Machine-Learning/House Price Regression'), statepoint={'5%': ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'ExterQual', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'BsmtQual', 'KitchenQual', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'GarageYrBlt', 'Fireplaces', 'GarageFinish', 'GarageType', 'HeatingQC', 'BsmtFinSF1', 'Foundation', 'LotFrontage', 'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'HalfBath', 'BsmtExposure', 'LotArea', 'LotShape', 'CentralAir', 'GarageCond', 'Electrical', 'PavedDrive', 'BsmtFullBath'], 'No of features': 35})

# %% [markdown]
# ### Select minimum variance as 2 %

# %%
selected_data = clean_data.store_selected_rsquared_limit(null_cleaned_data, rsquared_dataset, 2, "2rsq_final_data")
selected_data.head()
# Out:
#    SalePrice  OverallQual  GrLivArea  GarageCars ExterQual  GarageArea  \
# 0     208500            7       1710           2        Gd         548
# 1     181500            6       1262           2        TA         460
# 2     223500            7       1786           2        Gd         608
# 3     140000            7       1717           3        TA         642
# 4     250000            8       2198           3        Gd         836
#
#    TotalBsmtSF  1stFlrSF BsmtQual KitchenQual  ...  PavedDrive  BsmtFullBath  \
# 0          856       856       Gd          Gd  ...           Y             1
# 1         1262      1262       Gd          TA  ...           Y             0
# 2          920       920       Gd          Gd  ...           Y             1
# 3          756       961       TA          Gd  ...           Y             1
# 4         1145      1145       Gd          Gd  ...           Y             1
#
# ...

# %% [markdown]
# #### Store to project

# %%
features = list(selected_data.columns)
project.open_job({'2%': features, 'No of features': len(features)}).init()
# Out:
# Job(project=Project.get_project('/home/kidrahahjo/Machine-Learning/House Price Regression'), statepoint={'2%': ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'ExterQual', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'BsmtQual', 'KitchenQual', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'GarageYrBlt', 'Fireplaces', 'GarageFinish', 'GarageType', 'HeatingQC', 'BsmtFinSF1', 'Foundation', 'LotFrontage', 'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'HalfBath', 'BsmtExposure', 'LotArea', 'LotShape', 'CentralAir', 'GarageCond', 'Electrical', 'PavedDrive', 'BsmtFullBath', 'RoofStyle', 'BsmtUnfSF', 'SaleCondition', 'Neighborhood', 'GarageQual', 'HouseStyle', 'BedroomAbvGr', 'MSZoning'], 'No of features': 43})
